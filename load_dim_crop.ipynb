# %%
import os

from etl.transformations.common import create_spark, read_parquet

MINIO_STAGING_BUCKET = "staging"
# Out:
# /home/jovyan/work
# ['/home/jovyan/work', '/workspace', '/opt/conda/lib/python311.zip', '/opt/conda/lib/python3.11', '/opt/conda/lib/python3.11/lib-dynload', '', '/opt/conda/lib/python3.11/site-packages']

# %%
def main():
    spark = create_spark("load_dim_crop")

    df = read_parquet(
        spark,
        f"s3a://{MINIO_STAGING_BUCKET}/raw/postgres/crops/",
    )

    # View your schema and rows
    df.printSchema()
    df.show()

    # transformations

    spark.stop()


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 19
#      15     spark.stop()
#      18 if __name__ == "__main__":
# ---> 19     main()
#
# Cell In[2], line 2, in main()
#       1 def main():
# ----> 2     spark = create_spark("load_dim_crop")
#       4     df = read_parquet(
#       5         spark,
#       6         f"s3a://{MINIO_STAGING_BUCKET}/raw/postgres/crops/",
#       7     )
#       9     # View your schema and rows
#
# NameError: name 'create_spark' is not defined
