# %%
from pyspark.sql import SparkSession
 
spark = (
    SparkSession.builder
    .master("spark://urbangreen-spark-master:7077")
    .config("spark.driver.host", "urbangreen-jupyter")   # container name/hostname
    .config("spark.driver.bindAddress", "0.0.0.0")
    .config("spark.executor.memory", "1g")
    .config("spark.executor.cores", "1")
    .getOrCreate()
)
 
df = spark.range(1000)
print(df.count())
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/09 09:51:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [Stage 0:>                                                          (0 + 2) / 2]
# 1000
